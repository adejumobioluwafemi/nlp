# %% [markdown]
# ## Building a Basic Language Model
#
# let’s build a basic language model using trigrams of the Reuters corpus. Reuters corpus is a collection of 10,788 news documents totaling 1.3 million words.

# %%
from nltk.corpus import reuters
from nltk import bigrams, trigrams
from collections import Counter, defaultdict
import nltk
nltk.download('reuters')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package reuters to
# [nltk_data]     C:\Users\o.adejumobi\AppData\Roaming\nltk_data...
# [nltk_data]   Package reuters is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\o.adejumobi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
model = defaultdict(lambda: defaultdict(lambda: 0))

for sentence in reuters.sents():
    for w1, w2, w3 in trigrams(sentence, pad_right=True, pad_left=True):
        model[(w1, w2)][w3] +=1

for w1_w2 in model:
    total_count = float(sum(model[w1_w2].values()))
    for w3 in model[w1_w2]:
        model[w1_w2][w3] /= total_count

print(dict(model['today', 'the']))
# Out:
# {'public': 0.05555555555555555, 'European': 0.05555555555555555, 'Bank': 0.05555555555555555, 'price': 0.1111111111111111, 'emirate': 0.05555555555555555, 'overseas': 0.05555555555555555, 'newspaper': 0.05555555555555555, 'company': 0.16666666666666666, 'Turkish': 0.05555555555555555, 'increase': 0.05555555555555555, 'options': 0.05555555555555555, 'Higher': 0.05555555555555555, 'pound': 0.05555555555555555, 'Italian': 0.05555555555555555, 'time': 0.05555555555555555}

# %% [markdown]
# so we get predictions of all the possible words that can come next with their respective probabilities.
#
# Now, if we pick up the word "price" and again make a prediction for the words "the" and "price"

# %%
print(dict(model['the', 'price']))
# Out:
# {'yesterday': 0.004651162790697674, 'of': 0.3209302325581395, 'it': 0.05581395348837209, 'effect': 0.004651162790697674, 'cut': 0.009302325581395349, 'for': 0.05116279069767442, 'paid': 0.013953488372093023, 'to': 0.05581395348837209, 'increases': 0.013953488372093023, 'used': 0.004651162790697674, 'climate': 0.004651162790697674, '.': 0.023255813953488372, 'cuts': 0.009302325581395349, 'reductions': 0.004651162790697674, 'limit': 0.004651162790697674, 'now': 0.004651162790697674, 'moved': 0.004651162790697674, 'per': 0.013953488372093023, 'adjustments': 0.004651162790697674, '(': 0.009302325581395349, 'slumped': 0.004651162790697674, 'is': 0.018604651162790697, 'move': 0.004651162790697674, 'evolution': 0.004651162790697674, 'differentials': 0.009302325581395349, 'went': 0.004651162790697674, 'the': 0.013953488372093023, 'factor': 0.004651162790697674, 'Royal': 0.004651162790697674, ',': 0.018604651162790697, 'again': 0.004651162790697674, 'changes': 0.004651162790697674, 'holds': 0.004651162790697674, 'has': 0.009302325581395349, 'fall': 0.004651162790697674, '-': 0.004651162790697674, 'from': 0.004651162790697674, 'base': 0.004651162790697674, 'on': 0.004651162790697674, 'review': 0.004651162790697674, 'while': 0.004651162790697674, 'collapse': 0.004651162790697674, 'being': 0.004651162790697674, 'at': 0.023255813953488372, 'outlook': 0.004651162790697674, 'rises': 0.004651162790697674, 'drop': 0.004651162790697674, 'guaranteed': 0.004651162790697674, ',"': 0.004651162790697674, 'stayed': 0.009302325581395349, 'structure': 0.004651162790697674, 'and': 0.004651162790697674, 'could': 0.004651162790697674, 'related': 0.004651162790697674, 'hike': 0.004651162790697674, 'we': 0.004651162790697674, 'adjustment': 0.023255813953488372, 'policy': 0.004651162790697674, 'was': 0.009302325581395349, 'revision': 0.004651162790697674, 'freeze': 0.009302325581395349, 'led': 0.004651162790697674, 'action': 0.004651162790697674, 'zone': 0.004651162790697674, 'slump': 0.004651162790697674, 'had': 0.004651162790697674, 'difference': 0.004651162790697674, 'in': 0.004651162790697674, 'raise': 0.004651162790697674, 'increase': 0.009302325581395349, 'will': 0.013953488372093023, 'support': 0.004651162790697674, 'gap': 0.004651162790697674, 'would': 0.009302325581395349, 'projected': 0.004651162790697674, 'approached': 0.004651162790697674, 'instability': 0.004651162790697674}

# %% [markdown]
# If we keep following this process iteratively, we will soon have a coherent sentence! Here is a script to play around with generating a random piece of text using our n-gram model

# %%
import random

text = ["today", "the"]
sentence_finished = False

while not sentence_finished:
    r = random.random()
    print(f"r: {r}")
    accumulator = .0

    for word in model[tuple(text[-2:])].keys():
        # print(word)
        accumulator += model[tuple(text[-2:])][word]
        print(f"word: {word}, accumulator: {accumulator}\n")
        if accumulator >= r:
            text.append(word)
            break
    if text[-2:]==[None, None]:
        sentence_finished = True

print(' '.join([t for t in text if t]))
# Out:
# r: 0.2797987467606482
# word: public, accumulator: 0.05555555555555555
#
# word: European, accumulator: 0.1111111111111111
#
# word: Bank, accumulator: 0.16666666666666666
#
# word: price, accumulator: 0.2777777777777778
#
# word: emirate, accumulator: 0.33333333333333337
#
# r: 0.3356008957119615
# word: ', accumulator: 0.8
#
# r: 0.368195853682852
# word: s, accumulator: 1.0
#
# r: 0.8452855769153008
# word: exporting, accumulator: 0.00010845986984815618
#
# word: loss, accumulator: 0.0008676789587852494
#
# word: alleged, accumulator: 0.0020607375271149675
#
# word: foreign, accumulator: 0.008459869848156183
#
# word: largest, accumulator: 0.020824295010845987
#
# word: trade, accumulator: 0.03177874186550976
#
# word: biggest, accumulator: 0.0351409978308026
#
# word: concerns, accumulator: 0.03600867678958785
#
# word: two, accumulator: 0.03774403470715835
#
# word: ruling, accumulator: 0.039587852494577004
#
# word: avowed, accumulator: 0.03969631236442516
#
# word: deputy, accumulator: 0.04045553145336225
#
# word: grain, accumulator: 0.042082429501084595
#
# word: fruit, accumulator: 0.04219088937093275
#
# word: electric, accumulator: 0.04229934924078091
#
# word: improved, accumulator: 0.04262472885032538
#
# word: oil, accumulator: 0.048264642082429504
#
# word: second, accumulator: 0.053470715835141
#
# word: workers, accumulator: 0.053687635574837314
#
# word: elections, accumulator: 0.05379609544468547
#
# word: most, accumulator: 0.055748373101952284
#
# word: profitability, accumulator: 0.0559652928416486
#
# word: branch, accumulator: 0.056073752711496755
#
# word: large, accumulator: 0.05759219088937094
#
# word: largely, accumulator: 0.057700650759219096
#
# word: problems, accumulator: 0.058242950108459875
#
# word: version, accumulator: 0.05835140997830803
#
# word: the, accumulator: 0.05997830802603037
#
# word: (, accumulator: 0.06171366594360087
#
# word: Smithson, accumulator: 0.06182212581344903
#
# word: a, accumulator: 0.06952277657266812
#
# word: tender, accumulator: 0.07310195227765727
#
# word: allocation, accumulator: 0.07321041214750543
#
# word: existing, accumulator: 0.07429501084598698
#
# word: gold, accumulator: 0.07537960954446854
#
# word: life, accumulator: 0.07570498915401301
#
# word: industrial, accumulator: 0.07787418655097614
#
# word: Daily, accumulator: 0.07841648590021692
#
# word: Agriculture, accumulator: 0.07885032537960955
#
# word: top, accumulator: 0.0806941431670282
#
# word: exports, accumulator: 0.08438177874186552
#
# word: current, accumulator: 0.09229934924078093
#
# word: GNP, accumulator: 0.09273318872017355
#
# word: major, accumulator: 0.09620390455531455
#
# word: national, accumulator: 0.09783080260303689
#
# word: Neste, accumulator: 0.09793926247288505
#
# word: &, accumulator: 0.1144251626898048
#
# word: shares, accumulator: 0.11789587852494579
#
# word: profits, accumulator: 0.11973969631236445
#
# word: Oslo, accumulator: 0.1198481561822126
#
# word: plunge, accumulator: 0.12028199566160523
#
# word: full, accumulator: 0.12386117136659439
#
# word: moves, accumulator: 0.12440347071583517
#
# word: sole, accumulator: 0.12472885032537964
#
# word: lower, accumulator: 0.12537960954446858
#
# word: European, accumulator: 0.12689804772234278
#
# word: substantial, accumulator: 0.1271149674620391
#
# word: result, accumulator: 0.12722342733188724
#
# word: Bond, accumulator: 0.12733188720173538
#
# word: promised, accumulator: 0.12744034707158353
#
# word: five, accumulator: 0.12863340563991324
#
# word: doorstep, accumulator: 0.12874186550976138
#
# word: vital, accumulator: 0.1289587852494577
#
# word: petrodollar, accumulator: 0.12906724511930584
#
# word: palm, accumulator: 0.1293926247288503
#
# word: Redland, accumulator: 0.1296095444685466
#
# word: 156, accumulator: 0.12971800433839475
#
# word: close, accumulator: 0.1335140997830802
#
# word: appreciation, accumulator: 0.13470715835140992
#
# word: power, accumulator: 0.13514099783080255
#
# word: talks, accumulator: 0.13644251626898043
#
# word: headquarters, accumulator: 0.1367678958785249
#
# word: intentions, accumulator: 0.13709327548806935
#
# word: State, accumulator: 0.13752711496746198
#
# word: crude, accumulator: 0.138937093275488
#
# word: steel, accumulator: 0.13980477223427326
#
# word: shareholders, accumulator: 0.14164859002169192
#
# word: referral, accumulator: 0.14175704989154006
#
# word: estimate, accumulator: 0.14305856832971794
#
# word: outstanding, accumulator: 0.14815618221258128
#
# word: plans, accumulator: 0.149349240780911
#
# word: board, accumulator: 0.1574837310195227
#
# word: minority, accumulator: 0.15791757049891533
#
# word: retained, accumulator: 0.15802603036876348
#
# word: chief, accumulator: 0.1592190889370932
#
# word: Hong, accumulator: 0.15954446854663765
#
# word: expressed, accumulator: 0.1596529284164858
#
# word: court, accumulator: 0.15997830802603025
#
# word: Presidential, accumulator: 0.1600867678958784
#
# word: annual, accumulator: 0.16583514099783067
#
# word: central, accumulator: 0.16757049891540118
#
# word: weekly, accumulator: 0.1693058568329717
#
# word: award, accumulator: 0.16941431670281984
#
# word: 46, accumulator: 0.16984815618221247
#
# word: buoyant, accumulator: 0.17006507592190878
#
# word: average, accumulator: 0.1714750542299348
#
# word: fertilizer, accumulator: 0.17158351409978295
#
# word: value, accumulator: 0.17353579175704975
#
# word: voting, accumulator: 0.17462039045553132
#
# word: Inc, accumulator: 0.17581344902386103
#
# word: footwear, accumulator: 0.17592190889370918
#
# word: Commissioner, accumulator: 0.17603036876355732
#
# word: interim, accumulator: 0.17624728850325364
#
# word: investment, accumulator: 0.17841648590021675
#
# word: 50, accumulator: 0.1800433839479391
#
# word: meetings, accumulator: 0.1810195227765725
#
# word: first, accumulator: 0.18763557483731003
#
# word: pulp, accumulator: 0.18774403470715817
#
# word: expected, accumulator: 0.18796095444685448
#
# word: combined, accumulator: 0.1881778741865508
#
# word: supervisory, accumulator: 0.18850325379609525
#
# word: new, accumulator: 0.1920824295010844
#
# word: increase, accumulator: 0.19251626898047702
#
# word: subsidy, accumulator: 0.19262472885032517
#
# word: Sun, accumulator: 0.19295010845986962
#
# word: heating, accumulator: 0.19305856832971777
#
# word: sunflowerseed, accumulator: 0.1931670281995659
#
# word: 3, accumulator: 0.19457700650759194
#
# word: 4, accumulator: 0.19620390455531428
#
# word: 6, accumulator: 0.19783080260303662
#
# word: Digest, accumulator: 0.19804772234273293
#
# word: 200, accumulator: 0.19826464208242925
#
# word: initial, accumulator: 0.19880694143167002
#
# word: management, accumulator: 0.2030368763557481
#
# word: no, accumulator: 0.20563991323210384
#
# word: John, accumulator: 0.20585683297180016
#
# word: fall, accumulator: 0.20932754880694115
#
# word: Heyman, accumulator: 0.2094360086767893
#
# word: Conoco, accumulator: 0.2096529284164856
#
# word: chemical, accumulator: 0.21019522776572638
#
# word: stock, accumulator: 0.22624728850325349
#
# word: cocoa, accumulator: 0.22678958785249426
#
# word: harvest, accumulator: 0.2274403470715832
#
# word: number, accumulator: 0.2276572668112795
#
# word: suspension, accumulator: 0.2284164859002166
#
# word: net, accumulator: 0.23232104121475022
#
# word: trading, accumulator: 0.23373101952277625
#
# word: allowance, accumulator: 0.2338394793926244
#
# word: end, accumulator: 0.23459869848156148
#
# word: record, accumulator: 0.23882863340563956
#
# word: estimated, accumulator: 0.23980477223427296
#
# word: capacity, accumulator: 0.24067245119305822
#
# word: grains, accumulator: 0.24078091106290636
#
# word: authorized, accumulator: 0.24099783080260267
#
# word: mortgage, accumulator: 0.24132321041214713
#
# word: price, accumulator: 0.24251626898047685
#
# word: at, accumulator: 0.2428416485900213
#
# word: Agro, accumulator: 0.24295010845986945
#
# word: officers, accumulator: 0.24338394793926207
#
# word: receiving, accumulator: 0.24349240780911022
#
# word: common, accumulator: 0.25238611713665904
#
# word: U, accumulator: 0.2575921908893705
#
# word: not, accumulator: 0.26127982646420783
#
# word: Ministry, accumulator: 0.2621475054229931
#
# word: failure, accumulator: 0.26442516268980437
#
# word: semiconductor, accumulator: 0.26464208242950066
#
# word: inaction, accumulator: 0.2647505422993488
#
# word: decision, accumulator: 0.2700650759219084
#
# word: share, accumulator: 0.274620390455531
#
# word: closing, accumulator: 0.27570498915401254
#
# word: anything, accumulator: 0.2759219088937088
#
# word: been, accumulator: 0.27733188720173485
#
# word: basic, accumulator: 0.27765726681127934
#
# word: leading, accumulator: 0.2797180043383943
#
# word: Spanish, accumulator: 0.28004338394793876
#
# word: seven, accumulator: 0.2804772234273314
#
# word: market, accumulator: 0.2817787418655093
#
# word: ambassador, accumulator: 0.28210412147505376
#
# word: negotiating, accumulator: 0.28232104121475005
#
# word: restrictive, accumulator: 0.2824295010845982
#
# word: question, accumulator: 0.2827548806941427
#
# word: recent, accumulator: 0.28568329718004287
#
# word: decline, accumulator: 0.2874186550976134
#
# word: pacemakers, accumulator: 0.28752711496746153
#
# word: expertise, accumulator: 0.28763557483730967
#
# word: production, accumulator: 0.2896963123644246
#
# word: earnings, accumulator: 0.2932754880694138
#
# word: third, accumulator: 0.2952277657266806
#
# word: export, accumulator: 0.29945770065075866
#
# word: southwestern, accumulator: 0.2995661605206068
#
# word: Food, accumulator: 0.29999999999999943
#
# word: total, accumulator: 0.31138828633405585
#
# word: Colville, accumulator: 0.311496746203904
#
# word: proposal, accumulator: 0.3142082429501079
#
# word: interesting, accumulator: 0.3144251626898042
#
# word: something, accumulator: 0.31496746203904497
#
# word: 42, accumulator: 0.31529284164858945
#
# word: women, accumulator: 0.3154013015184376
#
# word: apparel, accumulator: 0.3158351409978302
#
# word: Socialist, accumulator: 0.31594360086767836
#
# word: program, accumulator: 0.316377440347071
#
# word: proposed, accumulator: 0.319848156182212
#
# word: statement, accumulator: 0.3234273318872012
#
# word: outlook, accumulator: 0.32396963123644196
#
# word: aerospace, accumulator: 0.32462039045553087
#
# word: communications, accumulator: 0.324728850325379
#
# word: Townson, accumulator: 0.32483731019522716
#
# word: 22, accumulator: 0.32559652928416427
#
# word: revenues, accumulator: 0.3260303687635569
#
# word: hard, accumulator: 0.3270065075921903
#
# word: targeted, accumulator: 0.32711496746203844
#
# word: purchase, accumulator: 0.32809110629067184
#
# word: pilots, accumulator: 0.3283080260303681
#
# word: previously, accumulator: 0.32950108459869787
#
# word: distilled, accumulator: 0.329609544468546
#
# word: spirits, accumulator: 0.32971800433839416
#
# word: gin, accumulator: 0.32993492407809044
#
# word: ", accumulator: 0.3317787418655091
#
# word: other, accumulator: 0.3331887201735351
#
# word: gas, accumulator: 0.33362255965292775
#
# word: National, accumulator: 0.33459869848156115
#
# word: April, accumulator: 0.33492407809110564
#
# word: 1986, accumulator: 0.34164859002169135
#
# word: financial, accumulator: 0.34555314533622494
#
# word: survival, accumulator: 0.3456616052060731
#
# word: Encor, accumulator: 0.34587852494576937
#
# word: filing, accumulator: 0.34609544468546566
#
# word: federal, accumulator: 0.34663774403470643
#
# word: purse, accumulator: 0.3467462039045546
#
# word: flexibility, accumulator: 0.34696312364425086
#
# word: figure, accumulator: 0.34793926247288426
#
# word: Gramm, accumulator: 0.3480477223427324
#
# word: Collander, accumulator: 0.34815618221258054
#
# word: coffee, accumulator: 0.3503253796095437
#
# word: 545, accumulator: 0.35043383947939183
#
# word: liquor, accumulator: 0.35054229934923997
#
# word: going, accumulator: 0.3527114967462031
#
# word: seasonally, accumulator: 0.35357917570498837
#
# word: plan, accumulator: 0.35618221258134414
#
# word: Venalum, accumulator: 0.3562906724511923
#
# word: little, accumulator: 0.3563991323210404
#
# word: Cable, accumulator: 0.35683297180043305
#
# word: lucrative, accumulator: 0.3569414316702812
#
# word: stance, accumulator: 0.3571583514099775
#
# word: car, accumulator: 0.35737527114967377
#
# word: authority, accumulator: 0.35791757049891454
#
# word: influence, accumulator: 0.3580260303687627
#
# word: ability, accumulator: 0.36030368763557397
#
# word: obstructionist, accumulator: 0.3604121475054221
#
# word: actions, accumulator: 0.36149674620390365
#
# word: economy, accumulator: 0.36540130151843725
#
# word: interest, accumulator: 0.3672451193058559
#
# word: main, accumulator: 0.37310195227765636
#
# word: EC, accumulator: 0.3742950108459861
#
# word: present, accumulator: 0.37548806941431584
#
# word: expansion, accumulator: 0.3757049891540121
#
# word: ordinary, accumulator: 0.3759219088937084
#
# word: stuck, accumulator: 0.37603036876355656
#
# word: sixth, accumulator: 0.3765726681127973
#
# word: capital, accumulator: 0.378416485900216
#
# word: privatisation, accumulator: 0.37895878524945675
#
# word: sweeping, accumulator: 0.37917570498915304
#
# word: forecast, accumulator: 0.3810195227765717
#
# word: view, accumulator: 0.38210412147505324
#
# word: downward, accumulator: 0.382646420824294
#
# word: resolve, accumulator: 0.3828633405639903
#
# word: Steinhaeuser, accumulator: 0.3830802603036866
#
# word: supposed, accumulator: 0.38340563991323107
#
# word: meeting, accumulator: 0.3868763557483721
#
# word: latest, accumulator: 0.38969631236442415
#
# word: accord, accumulator: 0.3901301518438168
#
# word: G, accumulator: 0.3911062906724502
#
# word: movement, accumulator: 0.3912147505422983
#
# word: in, accumulator: 0.39197396963123543
#
# word: Cohen, accumulator: 0.3920824295010836
#
# word: February, accumulator: 0.393058568329717
#
# word: harvests, accumulator: 0.3931670281995651
#
# word: Engine, accumulator: 0.39327548806941326
#
# word: shortfall, accumulator: 0.39425162689804666
#
# word: lows, accumulator: 0.3943600867678948
#
# word: New, accumulator: 0.3949023861171356
#
# word: position, accumulator: 0.3969631236442505
#
# word: BBC, accumulator: 0.39707158351409866
#
# word: hog, accumulator: 0.39804772234273206
#
# word: development, accumulator: 0.3984815618221247
#
# word: Finance, accumulator: 0.39956616052060623
#
# word: budget, accumulator: 0.40162689804772117
#
# word: package, accumulator: 0.40195227765726566
#
# word: rise, accumulator: 0.4055314533622548
#
# word: departure, accumulator: 0.4058568329717993
#
# word: finance, accumulator: 0.4063991323210401
#
# word: money, accumulator: 0.4074837310195216
#
# word: semi, accumulator: 0.4078091106290661
#
# word: employers, accumulator: 0.4080260303687624
#
# word: monetary, accumulator: 0.40911062906724394
#
# word: perceived, accumulator: 0.4092190889370921
#
# word: target, accumulator: 0.41084598698481445
#
# word: call, accumulator: 0.41117136659435893
#
# word: smelter, accumulator: 0.4114967462039034
#
# word: Trail, accumulator: 0.41193058568329605
#
# word: Herculaneum, accumulator: 0.4120390455531442
#
# word: prior, accumulator: 0.4122559652928405
#
# word: executive, accumulator: 0.41377440347071465
#
# word: family, accumulator: 0.4138828633405628
#
# word: tourism, accumulator: 0.41399132321041093
#
# word: oilseed, accumulator: 0.4145336225596517
#
# word: former, accumulator: 0.41540130151843696
#
# word: group, accumulator: 0.4164859002169185
#
# word: Counselor, accumulator: 0.4167028199566148
#
# word: move, accumulator: 0.41887201735357793
#
# word: Exxon, accumulator: 0.4191973969631224
#
# word: contract, accumulator: 0.41995661605205953
#
# word: Chancellor, accumulator: 0.42006507592190767
#
# word: presentation, accumulator: 0.4201735357917558
#
# word: afternoon, accumulator: 0.42028199566160396
#
# word: last, accumulator: 0.4214750542299337
#
# word: direction, accumulator: 0.42158351409978184
#
# word: that, accumulator: 0.42180043383947813
#
# word: Bradford, accumulator: 0.42190889370932627
#
# word: steelmaking, accumulator: 0.4220173535791744
#
# word: 1988, accumulator: 0.4223427331887189
#
# word: sales, accumulator: 0.4246203904555302
#
# word: done, accumulator: 0.4247288503253783
#
# word: given, accumulator: 0.42483731019522647
#
# word: officer, accumulator: 0.4257049891540117
#
# word: Foreign, accumulator: 0.42711496746203775
#
# word: policy, accumulator: 0.43015184381778615
#
# word: compensatory, accumulator: 0.4302603036876343
#
# word: Heublein, accumulator: 0.43036876355748244
#
# word: engine, accumulator: 0.4305856832971787
#
# word: operating, accumulator: 0.4322125813449011
#
# word: pipeline, accumulator: 0.4331887201735345
#
# word: Cereals, accumulator: 0.43329718004338263
#
# word: traditional, accumulator: 0.43394793926247155
#
# word: occurance, accumulator: 0.4340563991323197
#
# word: sportswear, accumulator: 0.43416485900216784
#
# word: store, accumulator: 0.434273318872016
#
# word: overall, accumulator: 0.4363340563991309
#
# word: >, accumulator: 0.4378524945770051
#
# word: beef, accumulator: 0.43893709327548663
#
# word: United, accumulator: 0.4394793926247274
#
# word: key, accumulator: 0.4401301518438163
#
# word: yield, accumulator: 0.44056399132320895
#
# word: session, accumulator: 0.44154013015184235
#
# word: Scallop, accumulator: 0.4416485900216905
#
# word: 623, accumulator: 0.44175704989153863
#
# word: 189, accumulator: 0.4418655097613868
#
# word: dismal, accumulator: 0.44208242950108306
#
# word: consumers, accumulator: 0.4421908893709312
#
# word: Donegan, accumulator: 0.44229934924077935
#
# word: estimates, accumulator: 0.442733188720172
#
# word: Export, accumulator: 0.4431670281995646
#
# word: Industrial, accumulator: 0.44360086767895723
#
# word: 73, accumulator: 0.4437093275488054
#
# word: negative, accumulator: 0.4438177874186535
#
# word: stake, accumulator: 0.44728850325379454
#
# word: level, accumulator: 0.44999999999999846
#
# word: modest, accumulator: 0.45032537960954294
#
# word: borrowings, accumulator: 0.4506507592190874
#
# word: float, accumulator: 0.4509761388286319
#
# word: M, accumulator: 0.45281995661605057
#
# word: Interim, accumulator: 0.45314533622559505
#
# word: procedures, accumulator: 0.4532537960954432
#
# word: previous, accumulator: 0.4542299349240766
#
# word: what, accumulator: 0.4544468546637729
#
# word: happening, accumulator: 0.45466377440346917
#
# word: lost, accumulator: 0.4547722342733173
#
# word: overnight, accumulator: 0.4549891540130136
#
# word: Washington, accumulator: 0.4553145336225581
#
# word: sharp, accumulator: 0.45694143167028045
#
# word: turmoil, accumulator: 0.4570498915401286
#
# word: wake, accumulator: 0.45715835140997674
#
# word: often, accumulator: 0.4572668112798249
#
# word: got, accumulator: 0.45748373101952117
#
# word: slide, accumulator: 0.4583514099783064
#
# word: difficult, accumulator: 0.45878524945769905
#
# word: reaction, accumulator: 0.45911062906724354
#
# word: Jones, accumulator: 0.4592190889370917
#
# word: ridiculous, accumulator: 0.4596529284164843
#
# word: renewed, accumulator: 0.46008676789587694
#
# word: comments, accumulator: 0.4619305856832956
#
# word: ports, accumulator: 0.4623644251626882
#
# word: edible, accumulator: 0.46247288503253636
#
# word: explanation, accumulator: 0.4625813449023845
#
# word: paid, accumulator: 0.46268980477223265
#
# word: causing, accumulator: 0.4627982646420808
#
# word: Customs, accumulator: 0.4630151843817771
#
# word: deficit, accumulator: 0.463665943600866
#
# word: official, accumulator: 0.4654013015184365
#
# word: announcement, accumulator: 0.4693058568329701
#
# word: leader, accumulator: 0.4695227765726664
#
# word: Coffee, accumulator: 0.46963123644251453
#
# word: registered, accumulator: 0.4697396963123627
#
# word: cotton, accumulator: 0.46995661605205896
#
# word: output, accumulator: 0.47147505422993313
#
# word: economic, accumulator: 0.47559652928416307
#
# word: deep, accumulator: 0.4757049891540112
#
# word: 1984, accumulator: 0.4759219088937075
#
# word: bond, accumulator: 0.4764642082429483
#
# word: obligations, accumulator: 0.4771149674620372
#
# word: president, accumulator: 0.4788503253796077
#
# word: disclosure, accumulator: 0.479067245119304
#
# word: assets, accumulator: 0.4822125813449005
#
# word: usual, accumulator: 0.4824295010845968
#
# word: balance, accumulator: 0.48362255965292655
#
# word: data, accumulator: 0.4844902386117118
#
# word: articles, accumulator: 0.4847071583514081
#
# word: offering, accumulator: 0.4850325379609526
#
# word: state, accumulator: 0.4890455531453344
#
# word: external, accumulator: 0.4902386117136641
#
# word: manufacturing, accumulator: 0.4905639913232086
#
# word: restructuring, accumulator: 0.49143167028199386
#
# word: bid, accumulator: 0.49511930585683117
#
# word: debtholders, accumulator: 0.49533622559652746
#
# word: debt, accumulator: 0.4988069414316685
#
# word: ., accumulator: 0.5004338394793908
#
# word: offer, accumulator: 0.5061822125813431
#
# word: 36, accumulator: 0.5065075921908876
#
# word: cost, accumulator: 0.5072668112798246
#
# word: Ifo, accumulator: 0.5074837310195209
#
# word: gains, accumulator: 0.5078091106290654
#
# word: spokeswoman, accumulator: 0.5079175704989136
#
# word: option, accumulator: 0.5085683297180026
#
# word: 129, accumulator: 0.5088937093275471
#
# word: Seagram, accumulator: 0.5090021691973953
#
# word: licence, accumulator: 0.5091106290672435
#
# word: holdings, accumulator: 0.5098698481561805
#
# word: reserves, accumulator: 0.5113882863340548
#
# word: selloff, accumulator: 0.511496746203903
#
# word: fault, accumulator: 0.5116052060737512
#
# word: markets, accumulator: 0.5119305856832956
#
# word: Gross, accumulator: 0.5126898047722327
#
# word: rapid, accumulator: 0.5131236442516253
#
# word: commitments, accumulator: 0.5132321041214735
#
# word: promise, accumulator: 0.513665943600866
#
# word: exchange, accumulator: 0.5147505422993476
#
# word: 16, accumulator: 0.5151843817787402
#
# word: support, accumulator: 0.5161605206073736
#
# word: change, accumulator: 0.5163774403470699
#
# word: Corporate, accumulator: 0.5164859002169181
#
# word: government, accumulator: 0.5180043383947923
#
# word: developing, accumulator: 0.5181127982646405
#
# word: positive, accumulator: 0.5182212581344887
#
# word: 9, accumulator: 0.5189804772234258
#
# word: general, accumulator: 0.5204989154013
#
# word: non, accumulator: 0.5208242950108445
#
# word: 82, accumulator: 0.5210412147505408
#
# word: subsequent, accumulator: 0.521149674620389
#
# word: principal, accumulator: 0.5220173535791742
#
# word: Stibnite, accumulator: 0.5221258134490224
#
# word: entire, accumulator: 0.5227765726681114
#
# word: and, accumulator: 0.5244034707158337
#
# word: has, accumulator: 0.5248373101952263
#
# word: is, accumulator: 0.5254880694143153
#
# word: ,, accumulator: 0.529501084598697
#
# word: product, accumulator: 0.5297180043383933
#
# word: operations, accumulator: 0.5315618221258119
#
# word: Conergic, accumulator: 0.5316702819956601
#
# word: backing, accumulator: 0.5321041214750527
#
# word: war, accumulator: 0.5324295010845972
#
# word: food, accumulator: 0.5327548806941417
#
# word: consolidated, accumulator: 0.5330802603036862
#
# word: consumer, accumulator: 0.5348156182212567
#
# word: March, accumulator: 0.535032537960953
#
# word: about, accumulator: 0.5353579175704974
#
# word: son, accumulator: 0.5354663774403456
#
# word: Paris, accumulator: 0.5362255965292827
#
# word: operator, accumulator: 0.5365509761388272
#
# word: performance, accumulator: 0.537852494577005
#
# word: chances, accumulator: 0.5379609544468532
#
# word: Smith, accumulator: 0.5380694143167014
#
# word: majority, accumulator: 0.538503253796094
#
# word: losses, accumulator: 0.539154013015183
#
# word: chairman, accumulator: 0.541323210412146
#
# word: hostile, accumulator: 0.5414316702819942
#
# word: Willa, accumulator: 0.5415401301518424
#
# word: recently, accumulator: 0.5417570498915387
#
# word: fiscal, accumulator: 0.5428416485900203
#
# word: nationwide, accumulator: 0.5429501084598685
#
# word: valuable, accumulator: 0.5430585683297167
#
# word: worth, accumulator: 0.5433839479392611
#
# word: ), accumulator: 0.5445770065075909
#
# word: accounting, accumulator: 0.5447939262472872
#
# word: RJ, accumulator: 0.5449023861171354
#
# word: International, accumulator: 0.5463123644251614
#
# word: so, accumulator: 0.5466377440347059
#
# word: draft, accumulator: 0.5467462039045541
#
# word: Office, accumulator: 0.5475054229934911
#
# word: reserve, accumulator: 0.5483731019522764
#
# word: telecommunications, accumulator: 0.548806941431669
#
# word: extensive, accumulator: 0.5489154013015172
#
# word: 1987, accumulator: 0.5513015184381767
#
# word: potentially, accumulator: 0.5514099783080249
#
# word: exploration, accumulator: 0.5518438177874174
#
# word: acquisitions, accumulator: 0.5519522776572656
#
# word: spending, accumulator: 0.5526030368763546
#
# word: 45, accumulator: 0.5529284164858991
#
# word: Brooklyn, accumulator: 0.5530368763557473
#
# word: three, accumulator: 0.5548806941431659
#
# word: home, accumulator: 0.5552060737527104
#
# word: acquistions, accumulator: 0.5553145336225586
#
# word: credibility, accumulator: 0.555639913232103
#
# word: judgement, accumulator: 0.5558568329717993
#
# word: ITC, accumulator: 0.5559652928416475
#
# word: final, accumulator: 0.5565075921908883
#
# word: preliminary, accumulator: 0.5568329718004328
#
# word: coordinator, accumulator: 0.556941431670281
#
# word: ongoing, accumulator: 0.5571583514099773
#
# word: plea, accumulator: 0.5572668112798255
#
# word: Supreme, accumulator: 0.5573752711496737
#
# word: suppliers, accumulator: 0.55759219088937
#
# word: chapter, accumulator: 0.5578091106290662
#
# word: business, accumulator: 0.5599783080260293
#
# word: subsidiary, accumulator: 0.5608459869848146
#
# word: compliance, accumulator: 0.5610629067245109
#
# word: Petroleum, accumulator: 0.5614967462039034
#
# word: 70, accumulator: 0.5618221258134479
#
# word: creditors, accumulator: 0.5620390455531442
#
# word: earlier, accumulator: 0.5627982646420813
#
# word: equity, accumulator: 0.563991323210411
#
# word: Eastern, accumulator: 0.5640997830802592
#
# word: stockholders, accumulator: 0.5644251626898037
#
# word: situations, accumulator: 0.5645336225596519
#
# word: activity, accumulator: 0.5648590021691964
#
# word: trades, accumulator: 0.5649674620390446
#
# word: futures, accumulator: 0.5651843817787409
#
# word: Chrysler, accumulator: 0.5652928416485891
#
# word: international, accumulator: 0.5680043383947929
#
# word: quota, accumulator: 0.5686550976138819
#
# word: breweries, accumulator: 0.5687635574837301
#
# word: broadly, accumulator: 0.5695227765726671
#
# word: goal, accumulator: 0.5699566160520597
#
# word: Economic, accumulator: 0.5716919739696302
#
# word: ban, accumulator: 0.5720173535791747
#
# word: index, accumulator: 0.5724511930585673
#
# word: 2, accumulator: 0.5750542299349231
#
# word: wholesale, accumulator: 0.5758134490238601
#
# word: Liberal, accumulator: 0.5760303687635564
#
# word: visit, accumulator: 0.5770065075921899
#
# word: protected, accumulator: 0.5772234273318861
#
# word: 0, accumulator: 0.5778741865509751
#
# word: 1, accumulator: 0.5795010845986974
#
# word: agricultural, accumulator: 0.57993492407809
#
# word: hitting, accumulator: 0.5800433839479382
#
# word: overreaction, accumulator: 0.5801518438177864
#
# word: spokesman, accumulator: 0.5809110629067235
#
# word: remarks, accumulator: 0.5835140997830792
#
# word: more, accumulator: 0.5841648590021682
#
# word: legislation, accumulator: 0.5842733188720164
#
# word: one, accumulator: 0.5853579175704979
#
# word: time, accumulator: 0.5855748373101942
#
# word: continuing, accumulator: 0.5860086767895868
#
# word: bow, accumulator: 0.586117136659435
#
# word: very, accumulator: 0.5864425162689795
#
# word: 99, accumulator: 0.5869848156182202
#
# word: assumption, accumulator: 0.5872017353579165
#
# word: clear, accumulator: 0.5874186550976128
#
# word: figures, accumulator: 0.5882863340563981
#
# word: fair, accumulator: 0.5883947939262463
#
# word: businesses, accumulator: 0.588937093275487
#
# word: unfair, accumulator: 0.589587852494576
#
# word: intervention, accumulator: 0.5904555314533613
#
# word: news, accumulator: 0.5906724511930576
#
# word: report, accumulator: 0.5928416485900206
#
# word: recommendations, accumulator: 0.5930585683297169
#
# word: Cleveland, accumulator: 0.5931670281995651
#
# word: 17, accumulator: 0.5936008676789577
#
# word: jungle, accumulator: 0.593817787418654
#
# word: 11, accumulator: 0.594577006507591
#
# word: Schlesinger, accumulator: 0.5950108459869836
#
# word: regulations, accumulator: 0.5952277657266799
#
# word: removal, accumulator: 0.5954446854663762
#
# word: swelling, accumulator: 0.5955531453362244
#
# word: competitiveness, accumulator: 0.5962039045553134
#
# word: Prospecting, accumulator: 0.5963123644251616
#
# word: rate, accumulator: 0.5970715835140986
#
# word: department, accumulator: 0.5972885032537949
#
# word: population, accumulator: 0.5977223427331875
#
# word: Colombo, accumulator: 0.5978308026030357
#
# word: buffer, accumulator: 0.5984815618221246
#
# word: fiduciary, accumulator: 0.5985900216919728
#
# word: special, accumulator: 0.5995661605206063
#
# word: recommendation, accumulator: 0.6004338394793916
#
# word: stated, accumulator: 0.600759219088936
#
# word: backlog, accumulator: 0.6010845986984805
#
# word: IMF, accumulator: 0.6013015184381768
#
# word: deadline, accumulator: 0.6015184381778731
#
# word: currently, accumulator: 0.6018438177874176
#
# word: renegotiation, accumulator: 0.6019522776572658
#
# word: ex, accumulator: 0.602060737527114
#
# word: edition, accumulator: 0.6023861171366585
#
# word: wholly, accumulator: 0.6032537960954437
#
# word: newly, accumulator: 0.6039045553145327
#
# word: British, accumulator: 0.6043383947939253
#
# word: surplus, accumulator: 0.605531453362255
#
# word: medium, accumulator: 0.6059652928416476
#
# word: return, accumulator: 0.6061822125813439
#
# word: division, accumulator: 0.6063991323210401
#
# word: senior, accumulator: 0.6072668112798254
#
# word: 12, accumulator: 0.6079175704989144
#
# word: cabinet, accumulator: 0.6084598698481551
#
# word: Department, accumulator: 0.6087852494576996
#
# word: Plume, accumulator: 0.6088937093275478
#
# word: Zimmerman, accumulator: 0.609002169197396
#
# word: softwood, accumulator: 0.6093275488069405
#
# word: lobby, accumulator: 0.6094360086767887
#
# word: 800, accumulator: 0.609652928416485
#
# word: Liemandt, accumulator: 0.6098698481561813
#
# word: Venice, accumulator: 0.6103036876355739
#
# word: willingness, accumulator: 0.6110629067245109
#
# word: summit, accumulator: 0.6112798264642072
#
# word: Stevens, accumulator: 0.6113882863340554
#
# word: mechanical, accumulator: 0.6114967462039036
#
# word: fundamental, accumulator: 0.6116052060737518
#
# word: refusal, accumulator: 0.6121475054229926
#
# word: 98, accumulator: 0.6122559652928408
#
# word: employees, accumulator: 0.6126898047722333
#
# word: LTV, accumulator: 0.6127982646420815
#
# word: probably, accumulator: 0.6132321041214741
#
# word: 31, accumulator: 0.6134490238611704
#
# word: royalty, accumulator: 0.6135574837310186
#
# word: Clayton, accumulator: 0.6136659436008668
#
# word: request, accumulator: 0.6159436008676781
#
# word: takeover, accumulator: 0.6168112798264633
#
# word: public, accumulator: 0.6172451193058559
#
# word: Midland, accumulator: 0.6174620390455522
#
# word: drag, accumulator: 0.6175704989154004
#
# word: larger, accumulator: 0.6177874186550967
#
# word: McGroarty, accumulator: 0.6178958785249449
#
# word: O, accumulator: 0.6181127982646412
#
# word: May, accumulator: 0.6183297180043374
#
# word: statements, accumulator: 0.6186550976138819
#
# word: issued, accumulator: 0.6191973969631227
#
# word: volatile, accumulator: 0.6193058568329709
#
# word: transactions, accumulator: 0.6194143167028191
#
# word: conviction, accumulator: 0.6195227765726673
#
# word: council, accumulator: 0.6202819956616044
#
# word: our, accumulator: 0.6203904555314526
#
# word: constitution, accumulator: 0.6204989154013008
#
# word: reluctance, accumulator: 0.6208242950108452
#
# word: premium, accumulator: 0.6210412147505415
#
# word: Linde, accumulator: 0.6211496746203897
#
# word: past, accumulator: 0.6215835140997823
#
# word: strong, accumulator: 0.6224511930585676
#
# word: reappointment, accumulator: 0.6225596529284158
#
# word: great, accumulator: 0.622668112798264
#
# word: fourth, accumulator: 0.6244034707158345
#
# word: Faw, accumulator: 0.6246203904555307
#
# word: Crown, accumulator: 0.624728850325379
#
# word: Oil, accumulator: 0.625488069414316
#
# word: King, accumulator: 0.6257049891540123
#
# word: efforts, accumulator: 0.6273318872017346
#
# word: strength, accumulator: 0.6288503253796088
#
# word: 66, accumulator: 0.628958785249457
#
# word: strategic, accumulator: 0.6290672451193052
#
# word: Central, accumulator: 0.6300433839479387
#
# word: ousted, accumulator: 0.6301518438177869
#
# word: sugar, accumulator: 0.6311279826464203
#
# word: lead, accumulator: 0.6315618221258129
#
# word: sudden, accumulator: 0.6317787418655092
#
# word: Bell, accumulator: 0.6318872017353574
#
# word: flagging, accumulator: 0.6319956616052056
#
# word: Lee, accumulator: 0.6321041214750538
#
# word: banks, accumulator: 0.6327548806941428
#
# word: director, accumulator: 0.632971800433839
#
# word: territorial, accumulator: 0.6330802603036872
#
# word: objections, accumulator: 0.6335140997830798
#
# word: Buddhist, accumulator: 0.633622559652928
#
# word: partners, accumulator: 0.6339479392624725
#
# word: ultimate, accumulator: 0.6340563991323207
#
# word: independent, accumulator: 0.6344902386117133
#
# word: seventh, accumulator: 0.6347071583514096
#
# word: barley, accumulator: 0.6348156182212578
#
# word: low, accumulator: 0.6352494577006503
#
# word: preferred, accumulator: 0.6355748373101948
#
# word: determination, accumulator: 0.6363340563991319
#
# word: only, accumulator: 0.6370932754880689
#
# word: recapitalization, accumulator: 0.6373101952277652
#
# word: hospital, accumulator: 0.6374186550976134
#
# word: Hutmann, accumulator: 0.6375271149674616
#
# word: Chrobok, accumulator: 0.6376355748373098
#
# word: adherence, accumulator: 0.6378524945770061
#
# word: Superior, accumulator: 0.6379609544468543
#
# word: approval, accumulator: 0.6382863340563988
#
# word: Halcon, accumulator: 0.638394793926247
#
# word: 81, accumulator: 0.6386117136659433
#
# word: inventory, accumulator: 0.6387201735357915
#
# word: bilateral, accumulator: 0.6389370932754878
#
# word: technical, accumulator: 0.6392624728850322
#
# word: highs, accumulator: 0.6393709327548804
#
# word: energy, accumulator: 0.640455531453362
#
# word: tonnage, accumulator: 0.6405639913232102
#
# word: SGF, accumulator: 0.6406724511930584
#
# word: fire, accumulator: 0.6407809110629066
#
# word: 58, accumulator: 0.6412147505422992
#
# word: daily, accumulator: 0.6418655097613881
#
# word: growth, accumulator: 0.6425162689804771
#
# word: USS, accumulator: 0.6430585683297179
#
# word: fate, accumulator: 0.6432754880694141
#
# word: policies, accumulator: 0.6441431670281994
#
# word: permitted, accumulator: 0.6442516268980476
#
# word: own, accumulator: 0.6459869848156181
#
# word: have, accumulator: 0.6460954446854663
#
# word: oilsands, accumulator: 0.6462039045553145
#
# word: levy, accumulator: 0.6463123644251627
#
# word: bismuth, accumulator: 0.6464208242950109
#
# word: marketing, accumulator: 0.6470715835140999
#
# word: Targeted, accumulator: 0.6471800433839481
#
# word: attitude, accumulator: 0.6477223427331888
#
# word: News, accumulator: 0.647830802603037
#
# word: revised, accumulator: 0.6490238611713668
#
# word: gross, accumulator: 0.6511930585683299
#
# word: levels, accumulator: 0.6516268980477224
#
# word: penalty, accumulator: 0.6517353579175706
#
# word: Union, accumulator: 0.6519522776572669
#
# word: Exchange, accumulator: 0.6520607375271151
#
# word: forthcoming, accumulator: 0.6522776572668114
#
# word: programme, accumulator: 0.6523861171366596
#
# word: soybean, accumulator: 0.6534707158351412
#
# word: illegal, accumulator: 0.6535791757049894
#
# word: opposition, accumulator: 0.6540130151843819
#
# word: cash, accumulator: 0.6548806941431672
#
# word: Sandvik, accumulator: 0.6549891540130154
#
# word: petroleum, accumulator: 0.655422993492408
#
# word: turnover, accumulator: 0.6557483731019524
#
# word: compensation, accumulator: 0.6559652928416487
#
# word: 14, accumulator: 0.6565075921908895
#
# word: rice, accumulator: 0.656832971800434
#
# word: drive, accumulator: 0.657483731019523
#
# word: highest, accumulator: 0.6578091106290674
#
# word: Brent, accumulator: 0.6580260303687637
#
# word: Kleinwort, accumulator: 0.6581344902386119
#
# word: election, accumulator: 0.6583514099783082
#
# word: ENI, accumulator: 0.6584598698481564
#
# word: 64, accumulator: 0.6586767895878527
#
# word: Marshall, accumulator: 0.658893709327549
#
# word: Directorate, accumulator: 0.6590021691973972
#
# word: system, accumulator: 0.6591106290672454
#
# word: oils, accumulator: 0.6592190889370936
#
# word: objectives, accumulator: 0.6594360086767899
#
# word: cakes, accumulator: 0.6595444685466381
#
# word: Western, accumulator: 0.6597613882863343
#
# word: available, accumulator: 0.6599783080260306
#
# word: prospective, accumulator: 0.6600867678958788
#
# word: customers, accumulator: 0.6603036876355751
#
# word: affiliate, accumulator: 0.6607375271149677
#
# word: posted, accumulator: 0.6620390455531455
#
# word: copper, accumulator: 0.6624728850325381
#
# word: fifth, accumulator: 0.6629067245119307
#
# word: projected, accumulator: 0.663123644251627
#
# word: Waterford, accumulator: 0.6632321041214752
#
# word: registration, accumulator: 0.6633405639913234
#
# word: Defence, accumulator: 0.6634490238611715
#
# word: crop, accumulator: 0.6646420824295013
#
# word: hurricane, accumulator: 0.6648590021691976
#
# word: Johnson, accumulator: 0.6655097613882865
#
# word: restricted, accumulator: 0.6656182212581347
#
# word: Cochrane, accumulator: 0.6657266811279829
#
# word: bank, accumulator: 0.6661605206073755
#
# word: 8, accumulator: 0.6665943600867681
#
# word: Launer, accumulator: 0.6667028199566163
#
# word: Citizens, accumulator: 0.6668112798264645
#
# word: action, accumulator: 0.6675704989154015
#
# word: case, accumulator: 0.668546637744035
#
# word: legal, accumulator: 0.6686550976138832
#
# word: trying, accumulator: 0.6687635574837314
#
# word: overture, accumulator: 0.6688720173535796
#
# word: letter, accumulator: 0.6691973969631241
#
# word: TRW, accumulator: 0.6693058568329723
#
# word: TriQuint, accumulator: 0.6694143167028205
#
# word: fastest, accumulator: 0.6695227765726687
#
# word: GDP, accumulator: 0.6698481561822132
#
# word: competitive, accumulator: 0.6699566160520614
#
# word: Work, accumulator: 0.6700650759219096
#
# word: economics, accumulator: 0.6704989154013021
#
# word: Louvre, accumulator: 0.6711496746203911
#
# word: domestic, accumulator: 0.6723427331887208
#
# word: reach, accumulator: 0.6725596529284171
#
# word: prime, accumulator: 0.6728850325379616
#
# word: unexpected, accumulator: 0.6729934924078098
#
# word: 5, accumulator: 0.6734273318872024
#
# word: looming, accumulator: 0.6735357917570506
#
# word: 320, accumulator: 0.6736442516268988
#
# word: private, accumulator: 0.6742950108459878
#
# word: desire, accumulator: 0.6748373101952285
#
# word: 10, accumulator: 0.6759219088937101
#
# word: custom, accumulator: 0.6760303687635583
#
# word: says, accumulator: 0.6762472885032546
#
# word: Supermarkets, accumulator: 0.676572668112799
#
# word: Board, accumulator: 0.6766811279826472
#
# word: operates, accumulator: 0.6767895878524954
#
# word: increased, accumulator: 0.6771149674620399
#
# word: to, accumulator: 0.6777657266811289
#
# word: needs, accumulator: 0.6781995661605215
#
# word: short, accumulator: 0.6788503253796104
#
# word: high, accumulator: 0.6798264642082439
#
# word: ship, accumulator: 0.6799349240780921
#
# word: yards, accumulator: 0.6801518438177884
#
# word: Lazere, accumulator: 0.6802603036876366
#
# word: loan, accumulator: 0.6810195227765736
#
# word: Miami, accumulator: 0.6811279826464218
#
# word: ministerial, accumulator: 0.68123644251627
#
# word: fixed, accumulator: 0.6815618221258145
#
# word: interests, accumulator: 0.682537960954448
#
# word: Texaco, accumulator: 0.6826464208242962
#
# word: 284, accumulator: 0.6827548806941444
#
# word: fees, accumulator: 0.6828633405639926
#
# word: completely, accumulator: 0.6829718004338408
#
# word: us, accumulator: 0.683080260303689
#
# word: anti, accumulator: 0.6837310195227779
#
# word: office, accumulator: 0.6842733188720187
#
# word: spokesperson, accumulator: 0.6843817787418669
#
# word: Wall, accumulator: 0.6847071583514114
#
# word: Atoka, accumulator: 0.6848156182212596
#
# word: OPEC, accumulator: 0.6854663774403486
#
# word: Only, accumulator: 0.6855748373101967
#
# word: representatives, accumulator: 0.685791757049893
#
# word: behalf, accumulator: 0.6862255965292856
#
# word: concessionary, accumulator: 0.6864425162689819
#
# word: natural, accumulator: 0.6866594360086782
#
# word: forestry, accumulator: 0.6867678958785264
#
# word: of, accumulator: 0.687201735357919
#
# word: mid, accumulator: 0.6876355748373115
#
# word: on, accumulator: 0.687960954446856
#
# word: nominee, accumulator: 0.6880694143167042
#
# word: securities, accumulator: 0.6882863340564005
#
# word: review, accumulator: 0.6889370932754895
#
# word: enforcement, accumulator: 0.6890455531453377
#
# word: 35th, accumulator: 0.6891540130151859
#
# word: Sterling, accumulator: 0.6892624728850341
#
# word: Canadian, accumulator: 0.6900216919739711
#
# word: hospitals, accumulator: 0.6901301518438193
#
# word: continued, accumulator: 0.6909978308026046
#
# word: rejection, accumulator: 0.6912147505423009
#
# word: agreement, accumulator: 0.6925162689804787
#
# word: any, accumulator: 0.6929501084598713
#
# word: job, accumulator: 0.6930585683297195
#
# word: University, accumulator: 0.6931670281995677
#
# word: directors, accumulator: 0.6939262472885047
#
# word: December, accumulator: 0.6949023861171382
#
# word: North, accumulator: 0.6959869848156197
#
# word: CD, accumulator: 0.6963123644251642
#
# word: bill, accumulator: 0.6969631236442532
#
# word: pledge, accumulator: 0.6971800433839495
#
# word: hotly, accumulator: 0.6972885032537977
#
# word: farm, accumulator: 0.6978308026030384
#
# word: jute, accumulator: 0.6979392624728866
#
# word: Victoria, accumulator: 0.6980477223427348
#
# word: Portland, accumulator: 0.698156182212583
#
# word: surge, accumulator: 0.6984815618221275
#
# word: 13, accumulator: 0.6991323210412165
#
# word: medical, accumulator: 0.6993492407809128
#
# word: statistics, accumulator: 0.699457700650761
#
# word: application, accumulator: 0.701518438177876
#
# word: asset, accumulator: 0.7016268980477242
#
# word: Sept, accumulator: 0.7017353579175724
#
# word: SEC, accumulator: 0.7019522776572686
#
# word: MedTec, accumulator: 0.7020607375271168
#
# word: 72, accumulator: 0.702169197396965
#
# word: unusual, accumulator: 0.7022776572668132
#
# word: regional, accumulator: 0.7027114967462058
#
# word: role, accumulator: 0.7036876355748393
#
# word: civic, accumulator: 0.7037960954446875
#
# word: charter, accumulator: 0.704121475054232
#
# word: Barnett, accumulator: 0.7042299349240801
#
# word: acquisition, accumulator: 0.7062906724511951
#
# word: electrical, accumulator: 0.7063991323210433
#
# word: worst, accumulator: 0.7069414316702841
#
# word: complex, accumulator: 0.7070498915401323
#
# word: ever, accumulator: 0.7071583514099805
#
# word: contribution, accumulator: 0.7077006507592213
#
# word: administrative, accumulator: 0.7078091106290695
#
# word: reformer, accumulator: 0.7079175704989177
#
# word: name, accumulator: 0.7086767895878547
#
# word: General, accumulator: 0.7087852494577029
#
# word: remaining, accumulator: 0.7097613882863364
#
# word: empire, accumulator: 0.7098698481561846
#
# word: KHJ, accumulator: 0.7099783080260328
#
# word: WOR, accumulator: 0.710086767895881
#
# word: Dalkon, accumulator: 0.7101952277657292
#
# word: yawning, accumulator: 0.7103036876355774
#
# word: crops, accumulator: 0.7104121475054256
#
# word: allegations, accumulator: 0.7107375271149701
#
# word: Neptune, accumulator: 0.7108459869848183
#
# word: Fox, accumulator: 0.7110629067245146
#
# word: 75, accumulator: 0.7111713665943628
#
# word: Unilever, accumulator: 0.711279826464211
#
# word: GE, accumulator: 0.7114967462039072
#
# word: outside, accumulator: 0.7116052060737554
#
# word: Management, accumulator: 0.7124728850325407
#
# word: members, accumulator: 0.712689804772237
#
# word: directorate, accumulator: 0.7130151843817815
#
# word: Cocoa, accumulator: 0.7131236442516297
#
# word: Vice, accumulator: 0.7132321041214779
#
# word: stability, accumulator: 0.7133405639913261
#
# word: northern, accumulator: 0.7136659436008705
#
# word: pact, accumulator: 0.7142082429501113
#
# word: reduction, accumulator: 0.7144251626898076
#
# word: flotation, accumulator: 0.7145336225596558
#
# word: Romero, accumulator: 0.714642082429504
#
# word: apparent, accumulator: 0.7149674620390485
#
# word: collapse, accumulator: 0.7154013015184411
#
# word: 32, accumulator: 0.7156182212581373
#
# word: unusually, accumulator: 0.7160520607375299
#
# word: remark, accumulator: 0.7163774403470744
#
# word: harm, accumulator: 0.7164859002169226
#
# word: seizure, accumulator: 0.7165943600867708
#
# word: shareholder, accumulator: 0.7169197396963153
#
# word: taken, accumulator: 0.7171366594360116
#
# word: crash, accumulator: 0.7173535791757079
#
# word: some, accumulator: 0.717462039045556
#
# word: whiplash, accumulator: 0.7175704989154043
#
# word: Dennis, accumulator: 0.7176789587852525
#
# word: doing, accumulator: 0.7178958785249487
#
# word: dollar, accumulator: 0.718112798264645
#
# word: cargo, accumulator: 0.7183297180043413
#
# word: handling, accumulator: 0.7184381778741895
#
# word: September, accumulator: 0.7186550976138858
#
# word: voluntary, accumulator: 0.718763557483734
#
# word: 84, accumulator: 0.7188720173535822
#
# word: comment, accumulator: 0.7195227765726712
#
# word: 150, accumulator: 0.7197396963123674
#
# word: leasehold, accumulator: 0.7198481561822156
#
# word: real, accumulator: 0.7209327548806972
#
# word: class, accumulator: 0.7212581344902417
#
# word: ICO, accumulator: 0.721475054229938
#
# word: farmers, accumulator: 0.7216919739696342
#
# word: 18, accumulator: 0.722234273318875
#
# word: Transamerica, accumulator: 0.7223427331887232
#
# word: River, accumulator: 0.7224511930585714
#
# word: exacerbated, accumulator: 0.7225596529284196
#
# word: postings, accumulator: 0.7227765726681159
#
# word: Information, accumulator: 0.7228850325379641
#
# word: firm, accumulator: 0.7229934924078123
#
# word: attack, accumulator: 0.7234273318872049
#
# word: conversion, accumulator: 0.7235357917570531
#
# word: an, accumulator: 0.7249457700650791
#
# word: planned, accumulator: 0.7260303687635606
#
# word: nominal, accumulator: 0.7264642082429532
#
# word: round, accumulator: 0.7265726681128014
#
# word: wishes, accumulator: 0.7266811279826496
#
# word: Aschoff, accumulator: 0.7267895878524978
#
# word: heavy, accumulator: 0.7271149674620423
#
# word: entry, accumulator: 0.7273318872017386
#
# word: agriculture, accumulator: 0.7279826464208276
#
# word: principals, accumulator: 0.7280911062906757
#
# word: preparation, accumulator: 0.728199566160524
#
# word: 60, accumulator: 0.7284164859002202
#
# word: cattle, accumulator: 0.7286334056399165
#
# word: criticisms, accumulator: 0.7287418655097647
#
# word: Silkworm, accumulator: 0.728958785249461
#
# word: naval, accumulator: 0.7290672451193092
#
# word: administration, accumulator: 0.7291757049891574
#
# word: liquefied, accumulator: 0.7292841648590056
#
# word: working, accumulator: 0.7296095444685501
#
# word: their, accumulator: 0.7297180043383983
#
# word: Advantage, accumulator: 0.7298264642082465
#
# word: Fine, accumulator: 0.730151843817791
#
# word: weekend, accumulator: 0.7303687635574873
#
# word: stubborn, accumulator: 0.7304772234273355
#
# word: hand, accumulator: 0.730911062906728
#
# word: presidential, accumulator: 0.7311279826464243
#
# word: important, accumulator: 0.7314533622559688
#
# word: status, accumulator: 0.7318872017353614
#
# word: head, accumulator: 0.7319956616052096
#
# word: much, accumulator: 0.7322125813449059
#
# word: leveraged, accumulator: 0.732321041214754
#
# word: retaliatory, accumulator: 0.7324295010846023
#
# word: counsel, accumulator: 0.7326464208242985
#
# word: criticism, accumulator: 0.7328633405639948
#
# word: inability, accumulator: 0.7331887201735393
#
# word: next, accumulator: 0.7337310195227801
#
# word: injection, accumulator: 0.7338394793926283
#
# word: Prudhoe, accumulator: 0.7341648590021728
#
# word: right, accumulator: 0.7347071583514135
#
# word: petition, accumulator: 0.7348156182212617
#
# word: retaliation, accumulator: 0.7349240780911099
#
# word: trip, accumulator: 0.7350325379609581
#
# word: Arco, accumulator: 0.7351409978308063
#
# word: query, accumulator: 0.7352494577006545
#
# word: Iranian, accumulator: 0.7354663774403508
#
# word: publishing, accumulator: 0.735574837310199
#
# word: response, accumulator: 0.7368763557483768
#
# word: harbors, accumulator: 0.7370932754880731
#
# word: territory, accumulator: 0.7372017353579213
#
# word: War, accumulator: 0.7374186550976176
#
# word: up, accumulator: 0.7376355748373139
#
# word: Brown, accumulator: 0.7377440347071621
#
# word: seat, accumulator: 0.7378524945770103
#
# word: like, accumulator: 0.7380694143167066
#
# word: Rostam, accumulator: 0.7381778741865548
#
# word: Southern, accumulator: 0.738286334056403
#
# word: differential, accumulator: 0.7385032537960993
#
# word: 210, accumulator: 0.7386117136659475
#
# word: party, accumulator: 0.7387201735357957
#
# word: hit, accumulator: 0.738937093275492
#
# word: Lambert, accumulator: 0.7390455531453402
#
# word: Nicol, accumulator: 0.7391540130151883
#
# word: missile, accumulator: 0.7392624728850365
#
# word: quarter, accumulator: 0.739587852494581
#
# word: succesfull, accumulator: 0.7396963123644292
#
# word: Calona, accumulator: 0.7398047722342774
#
# word: California, accumulator: 0.7399132321041256
#
# word: richest, accumulator: 0.7402386117136701
#
# word: Ronnskar, accumulator: 0.7403470715835183
#
# ...
#
# word: totalled, accumulator: 0.7671366594360146
#
# word: are, accumulator: 0.7673535791757109
#
# word: Rasmussen, accumulator: 0.7674620390455591
#
# word: slower, accumulator: 0.7675704989154073
#
# word: world, accumulator: 0.7678958785249518
#
# word: dividend, accumulator: 0.7683297180043444
#
# word: commitment, accumulator: 0.7688720173535851
#
# word: Nelissen, accumulator: 0.7689804772234333
#
# word: advantage, accumulator: 0.7690889370932815
#
# word: strategy, accumulator: 0.770065075921915
#
# word: sagging, accumulator: 0.7701735357917632
#
# word: longer, accumulator: 0.7704989154013077
#
# word: 149, accumulator: 0.770715835141004
#
# word: boards, accumulator: 0.7708242950108521
#
# word: scrutiny, accumulator: 0.7709327548807003
#
# word: struggle, accumulator: 0.7710412147505485
#
# word: purchases, accumulator: 0.7715835140997893
#
# word: impression, accumulator: 0.7716919739696375
#
# word: dealings, accumulator: 0.7718004338394857
#
# word: clothing, accumulator: 0.7719088937093339
#
# word: hedging, accumulator: 0.7720173535791821
#
# word: engineering, accumulator: 0.7721258134490303
#
# word: Bay, accumulator: 0.7729934924078156
#
# word: primiary, accumulator: 0.7731019522776638
#
# word: 500, accumulator: 0.7734273318872082
#
# word: southern, accumulator: 0.7736442516269045
#
# word: four, accumulator: 0.7747288503253861
#
# word: prospects, accumulator: 0.7749457700650824
#
# word: results, accumulator: 0.7760303687635639
#
# word: pricing, accumulator: 0.7762472885032602
#
# word: widening, accumulator: 0.7764642082429565
#
# word: wage, accumulator: 0.7766811279826528
#
# word: OCS, accumulator: 0.776789587852501
#
# word: good, accumulator: 0.7770065075921972
#
# word: base, accumulator: 0.7772234273318935
#
# word: planting, accumulator: 0.7773318872017417
#
# word: planted, accumulator: 0.7774403470715899
#
# word: NATO, accumulator: 0.7775488069414381
#
# word: 700, accumulator: 0.7776572668112863
#
# word: silver, accumulator: 0.7777657266811345
#
# word: Delivery, accumulator: 0.7778741865509827
#
# word: which, accumulator: 0.7779826464208309
#
# word: pace, accumulator: 0.7780911062906791
#
# word: drop, accumulator: 0.7785249457700717
#
# word: radio, accumulator: 0.7786334056399199
#
# word: telephone, accumulator: 0.7789587852494644
#
# word: Siemens, accumulator: 0.779392624728857
#
# word: AB, accumulator: 0.7795010845987052
#
# word: Consumer, accumulator: 0.7796095444685534
#
# word: fahrenheit, accumulator: 0.7797180043384015
#
# word: for, accumulator: 0.7799349240780978
#
# word: Kaohsiung, accumulator: 0.780043383947946
#
# word: South, accumulator: 0.7804772234273386
#
# word: continental, accumulator: 0.7806941431670349
#
# word: warehouses, accumulator: 0.7808026030368831
#
# word: surging, accumulator: 0.7809110629067313
#
# word: parallel, accumulator: 0.7810195227765795
#
# word: increasingly, accumulator: 0.7814533622559721
#
# word: Burgan, accumulator: 0.7815618221258203
#
# word: success, accumulator: 0.7817787418655165
#
# word: parent, accumulator: 0.7826464208243018
#
# word: tendency, accumulator: 0.7829718004338463
#
# word: steep, accumulator: 0.7838394793926315
#
# word: belief, accumulator: 0.7840563991323278
#
# word: 27, accumulator: 0.7843817787418723
#
# word: BTR, accumulator: 0.7844902386117205
#
# word: certainly, accumulator: 0.7847071583514168
#
# word: lifestyle, accumulator: 0.7849240780911131
#
# word: words, accumulator: 0.7852494577006576
#
# word: reference, accumulator: 0.7854663774403539
#
# word: growing, accumulator: 0.7857917570498983
#
# word: nosedive, accumulator: 0.7859002169197465
#
# word: Rite, accumulator: 0.7860086767895947
#
# word: Edwards, accumulator: 0.7861171366594429
#
# word: vast, accumulator: 0.7862255965292911
#
# word: Prime, accumulator: 0.7864425162689874
#
# word: Friday, accumulator: 0.7866594360086837
#
# word: 169, accumulator: 0.78687635574838
#
# word: chartering, accumulator: 0.7869848156182282
#
# word: 20, accumulator: 0.787527114967469
#
# word: image, accumulator: 0.7876355748373172
#
# word: ailing, accumulator: 0.7880694143167097
#
# word: temporary, accumulator: 0.7881778741865579
#
# word: middle, accumulator: 0.7883947939262542
#
# word: quoted, accumulator: 0.7885032537961024
#
# word: just, accumulator: 0.7891540130151914
#
# word: Wallenberg, accumulator: 0.7893709327548877
#
# word: Rubber, accumulator: 0.789587852494584
#
# word: founder, accumulator: 0.7898047722342803
#
# word: hydrocracker, accumulator: 0.7899132321041284
#
# word: visible, accumulator: 0.7904555314533692
#
# word: reply, accumulator: 0.7905639913232174
#
# word: Tate, accumulator: 0.7907809110629137
#
# word: 630, accumulator: 0.7908893709327619
#
# word: half, accumulator: 0.7913232104121545
#
# word: understanding, accumulator: 0.7914316702820027
#
# word: use, accumulator: 0.7915401301518509
#
# word: managers, accumulator: 0.7917570498915472
#
# word: tumble, accumulator: 0.7919739696312434
#
# word: bullishness, accumulator: 0.7920824295010916
#
# word: holding, accumulator: 0.7927331887201806
#
# word: throttle, accumulator: 0.7928416485900288
#
# word: small, accumulator: 0.7938177874186623
#
# word: exercise, accumulator: 0.7942516268980548
#
# word: history, accumulator: 0.7946854663774474
#
# word: river, accumulator: 0.7947939262472956
#
# word: lack, accumulator: 0.7950108459869919
#
# word: Investors, accumulator: 0.7954446854663845
#
# word: syndicate, accumulator: 0.7955531453362327
#
# word: counselor, accumulator: 0.7956616052060809
#
# word: late, accumulator: 0.7959869848156254
#
# word: profit, accumulator: 0.7967462039045624
#
# word: refinery, accumulator: 0.7975054229934995
#
# word: book, accumulator: 0.7977223427331958
#
# word: 584, accumulator: 0.797830802603044
#
# word: Select, accumulator: 0.7980477223427402
#
# word: fundamentals, accumulator: 0.7981561822125884
#
# word: objective, accumulator: 0.7983731019522847
#
# word: intention, accumulator: 0.7986984815618292
#
# word: American, accumulator: 0.7995661605206145
#
# word: fast, accumulator: 0.7997830802603108
#
# word: 870p, accumulator: 0.799891540130159
#
# word: principle, accumulator: 0.8000000000000071
#
# word: almost, accumulator: 0.8003253796095516
#
# word: potential, accumulator: 0.8004338394793998
#
# word: still, accumulator: 0.8009761388286406
#
# word: citrus, accumulator: 0.8010845986984888
#
# word: Florida, accumulator: 0.801193058568337
#
# word: another, accumulator: 0.8014099783080333
#
# word: sanctions, accumulator: 0.8015184381778815
#
# word: amazing, accumulator: 0.8016268980477297
#
# word: Brusca, accumulator: 0.8017353579175779
#
# word: Chas, accumulator: 0.8018438177874261
#
# word: distribution, accumulator: 0.8023861171366669
#
# word: 1983, accumulator: 0.802494577006515
#
# word: 17th, accumulator: 0.8026030368763633
#
# word: Fairfield, accumulator: 0.8027114967462115
#
# word: known, accumulator: 0.8028199566160596
#
# word: account, accumulator: 0.8034707158351486
#
# word: Carnival, accumulator: 0.8035791757049968
#
# word: yearly, accumulator: 0.8039045553145413
#
# word: 412, accumulator: 0.8040130151843895
#
# word: Third, accumulator: 0.8041214750542377
#
# word: facilities, accumulator: 0.804338394793934
#
# word: employment, accumulator: 0.8046637744034785
#
# word: housing, accumulator: 0.804989154013023
#
# word: sugarcane, accumulator: 0.8050976138828712
#
# word: affairs, accumulator: 0.8053145336225674
#
# word: critics, accumulator: 0.8054229934924156
#
# word: self, accumulator: 0.8055314533622638
#
# word: huge, accumulator: 0.8063991323210491
#
# word: booming, accumulator: 0.8065075921908973
#
# word: participation, accumulator: 0.8071583514099863
#
# word: liberalised, accumulator: 0.8072668112798345
#
# word: currency, accumulator: 0.807700650759227
#
# word: won, accumulator: 0.8078091106290752
#
# word: managing, accumulator: 0.8079175704989234
#
# word: 850, accumulator: 0.8081344902386197
#
# word: will, accumulator: 0.8086767895878605
#
# word: chips, accumulator: 0.8087852494577087
#
# word: credit, accumulator: 0.8095444685466457
#
# word: furnace, accumulator: 0.8096529284164939
#
# word: Sugar, accumulator: 0.8098698481561902
#
# word: raw, accumulator: 0.8101952277657347
#
# word: because, accumulator: 0.810412147505431
#
# word: NZFP, accumulator: 0.8105206073752792
#
# word: pipe, accumulator: 0.8106290672451274
#
# word: occurred, accumulator: 0.8107375271149756
#
# word: Minister, accumulator: 0.8112798264642164
#
# word: attempt, accumulator: 0.8118221258134571
#
# word: attempts, accumulator: 0.8121475054230016
#
# word: aim, accumulator: 0.8125813449023942
#
# word: computer, accumulator: 0.8127982646420905
#
# word: wheat, accumulator: 0.8136659436008757
#
# word: limits, accumulator: 0.8137744034707239
#
# word: interstate, accumulator: 0.8139913232104202
#
# word: 92, accumulator: 0.8144251626898128
#
# word: import, accumulator: 0.8151843817787499
#
# word: Democratic, accumulator: 0.815292841648598
#
# word: ending, accumulator: 0.8154013015184463
#
# word: 459, accumulator: 0.8155097613882945
#
# word: 125, accumulator: 0.8157266811279907
#
# word: depositors, accumulator: 0.8158351409978389
#
# word: Texas, accumulator: 0.8160520607375352
#
# word: possible, accumulator: 0.8164859002169278
#
# word: November, accumulator: 0.8167028199566241
#
# word: Collier, accumulator: 0.8168112798264723
#
# word: welcome, accumulator: 0.8169197396963205
#
# word: 59, accumulator: 0.8170281995661687
#
# word: period, accumulator: 0.8171366594360169
#
# word: financing, accumulator: 0.8173535791757132
#
# word: SCM, accumulator: 0.8174620390455614
#
# word: temporao, accumulator: 0.8175704989154096
#
# word: Westin, accumulator: 0.8177874186551058
#
# word: merger, accumulator: 0.8183297180043466
#
# word: concern, accumulator: 0.8185466377440429
#
# word: oldest, accumulator: 0.8186550976138911
#
# word: airline, accumulator: 0.8188720173535874
#
# word: aggressive, accumulator: 0.8189804772234356
#
# word: ,", accumulator: 0.8193058568329801
#
# word: immediate, accumulator: 0.8194143167028283
#
# word: Airbus, accumulator: 0.8195227765726765
#
# word: 29, accumulator: 0.8196312364425247
#
# word: sale, accumulator: 0.8208242950108544
#
# word: slate, accumulator: 0.8209327548807026
#
# word: warrants, accumulator: 0.8210412147505508
#
# word: 710, accumulator: 0.8212581344902471
#
# word: falling, accumulator: 0.8213665943600953
#
# word: sweetened, accumulator: 0.8215835140997916
#
# word: insurance, accumulator: 0.8220173535791842
#
# word: termination, accumulator: 0.8221258134490323
#
# word: Corp, accumulator: 0.8231019522776658
#
# word: also, accumulator: 0.8233188720173621
#
# word: Perkins, accumulator: 0.8234273318872103
#
# word: Champlin, accumulator: 0.8236442516269066
#
# word: systems, accumulator: 0.8237527114967548
#
# word: fully, accumulator: 0.8239696312364511
#
# word: Thermoplastic, accumulator: 0.8240780911062993
#
# word: shut, accumulator: 0.8241865509761475
#
# word: Energy, accumulator: 0.8245119305856919
#
# word: manager, accumulator: 0.8247288503253882
#
# word: trial, accumulator: 0.8248373101952364
#
# word: Cotton, accumulator: 0.8249457700650846
#
# word: aircraft, accumulator: 0.8250542299349328
#
# word: health, accumulator: 0.8258134490238699
#
# word: offshore, accumulator: 0.8264642082429589
#
# word: operational, accumulator: 0.826572668112807
#
# word: all, accumulator: 0.8267895878525033
#
# word: opening, accumulator: 0.8270065075921996
#
# word: surprise, accumulator: 0.8274403470715922
#
# word: coupon, accumulator: 0.8275488069414404
#
# word: excess, accumulator: 0.8276572668112886
#
# word: 175, accumulator: 0.8277657266811368
#
# word: people, accumulator: 0.827874186550985
#
# word: vice, accumulator: 0.8283080260303776
#
# word: Congress, accumulator: 0.8285249457700739
#
# word: imports, accumulator: 0.8296095444685554
#
# word: AEG, accumulator: 0.8297180043384036
#
# word: exposure, accumulator: 0.8300433839479481
#
# word: advance, accumulator: 0.8301518438177963
#
# word: proportion, accumulator: 0.8302603036876445
#
# word: tin, accumulator: 0.830585683297189
#
# word: shipbreaking, accumulator: 0.8306941431670372
#
# word: nine, accumulator: 0.8310195227765816
#
# word: routine, accumulator: 0.8312364425162779
#
# word: excavator, accumulator: 0.8313449023861261
#
# word: reign, accumulator: 0.8315618221258224
#
# word: electrotechnical, accumulator: 0.8316702819956706
#
# word: Consolidated, accumulator: 0.8317787418655188
#
# word: overriding, accumulator: 0.831887201735367
#
# word: regular, accumulator: 0.8327548806941523
#
# word: producer, accumulator: 0.8328633405640005
#
# word: Hambrecht, accumulator: 0.8329718004338487
#
# word: relative, accumulator: 0.8330802603036969
#
# word: joint, accumulator: 0.8334056399132413
#
# word: oilseeds, accumulator: 0.8335140997830895
#
# word: original, accumulator: 0.8339479392624821
#
# word: harvested, accumulator: 0.8341648590021784
#
# word: 671, accumulator: 0.8343817787418747
#
# word: crushing, accumulator: 0.834598698481571
#
# word: Traffic, accumulator: 0.8347071583514192
#
# word: 67, accumulator: 0.8348156182212674
#
# word: global, accumulator: 0.8349240780911156
#
# word: negotiations, accumulator: 0.8350325379609638
#
# word: frost, accumulator: 0.8353579175705083
#
# word: expectations, accumulator: 0.8356832971800527
#
# word: Creations, accumulator: 0.8357917570499009
#
# word: reported, accumulator: 0.8360086767895972
#
# word: cut, accumulator: 0.836550976138838
#
# word: lowering, accumulator: 0.8366594360086862
#
# word: nuclear, accumulator: 0.8367678958785344
#
# word: Manufacturers, accumulator: 0.8368763557483826
#
# word: Bank, accumulator: 0.8373101952277752
#
# word: Bancshares, accumulator: 0.8374186550976234
#
# word: analysis, accumulator: 0.8375271149674716
#
# word: 460, accumulator: 0.8376355748373198
#
# word: ODC, accumulator: 0.837852494577016
#
# word: Vestar, accumulator: 0.8379609544468642
#
# word: momentum, accumulator: 0.8381778741865605
#
# word: poorest, accumulator: 0.8383947939262568
#
# word: salary, accumulator: 0.8386117136659531
#
# word: E, accumulator: 0.8387201735358013
#
# word: Executive, accumulator: 0.8391540130151939
#
# word: Flexi, accumulator: 0.8392624728850421
#
# word: 40, accumulator: 0.8411062906724607
#
# word: deal, accumulator: 0.8412147505423089
#
# word: minister, accumulator: 0.8413232104121571
#
# word: instant, accumulator: 0.8414316702820053
#
# word: hearing, accumulator: 0.8415401301518535
#
# word: Kaul, accumulator: 0.8416485900217017
#
# word: Rosenberg, accumulator: 0.8417570498915499
#
# word: internal, accumulator: 0.8421908893709424
#
# word: products, accumulator: 0.8427331887201832
#
# word: air, accumulator: 0.8428416485900314
#
# word: Stant, accumulator: 0.8429501084598796
#
# word: fee, accumulator: 0.8431670281995759
#
# word: pending, accumulator: 0.8434924078091204
#
# word: discussions, accumulator: 0.8438177874186649
#
# word: Fidelcor, accumulator: 0.8439262472885131
#
# word: 100, accumulator: 0.8444685466377538
#
# word: USDA, accumulator: 0.8446854663774501
#
# word: 76, accumulator: 0.8447939262472983
#
# word: unilateral, accumulator: 0.8452277657266909
#
# word: after, accumulator: 0.8453362255965391
#
# r: 0.11390734840451688
# word: -, accumulator: 1.0
#
# r: 0.8464650626299787
# word: tax, accumulator: 0.9841269841269841
#
# r: 0.1581714144298828
# word: profit, accumulator: 0.32599118942731276
#
# r: 0.3682418902768959
# word: by, accumulator: 0.012987012987012988
#
# word: 105, accumulator: 0.05194805194805195
#
# word: for, accumulator: 0.09090909090909091
#
# word: to, accumulator: 0.1168831168831169
#
# word: of, accumulator: 0.2857142857142857
#
# word: 376, accumulator: 0.3246753246753247
#
# word: with, accumulator: 0.33766233766233766
#
# word: 312, accumulator: 0.35064935064935066
#
# word: 27, accumulator: 0.36363636363636365
#
# word: 995, accumulator: 0.37662337662337664
#
# r: 0.2418300072135241
# word: ., accumulator: 1.0
#
# r: 0.1864295705352903
# word: 2, accumulator: 0.3333333333333333
#
# r: 0.27788869024759644
# word: billion, accumulator: 0.10931174089068826
#
# word: mln, accumulator: 0.6857287449392713
#
# r: 0.5940213652824891
# word: vs, accumulator: 0.33187006145741876
#
# word: Merchanting, accumulator: 0.3327480245829675
#
# word: debit, accumulator: 0.3345039508340649
#
# word: previously, accumulator: 0.33538191395961364
#
# word: Avg, accumulator: 0.38805970149253727
#
# word: dlrs, accumulator: 0.5478489903424055
#
# word: tonnes, accumulator: 0.5671641791044775
#
# word: to, accumulator: 0.5689201053555749
#
# word: hectares, accumulator: 0.5741878841088672
#
# word: tonne, accumulator: 0.5759438103599647
#
# word: None, accumulator: 0.6172080772607549
#
# r: 0.7338319356476243
# word: None, accumulator: 1.0
#
# today the emirate ' s after - tax profit 995 . 2 mln
